# %% [markdown]
# # Neural Network Layers and Weights dimensions

# %% [markdown]
# The purpose of this notebook is to clarify what dimensions to expect while working with W and b being passed from one layer to another.
#
# Remember:
# * **W_**: weight MATRIX
# * **w_**: weight VECTOR or single weight

# %%
! python /workspaces/deeplearningai-machine-learning/02_advanced_learning_algorithms/03_nn_dimensions.py
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1763562275.964910    8803 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1763562275.968670    8803 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# AttributeError: 'MessageFactory' object has no attribute 'GetPrototype'
# Tensorflow version : 2.18.0
# ...
